# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('data/graduates.csv'))
df = df[df['Salaries.Highest'] > 0.0]
df = df[df['Year'] == 2015]
df
# Out:
# 9
# 484                                    342751
# 485                                    215384
# 486                                     49855
# 487                                      6202
# 488                                     13774
# 489                                      4251
# 490                                     45588
# 491                                     27058
# 492                                      1797
# 493                                     87999
# 494                                     75286
# 495                                     26974
# 496                                    240458
# 497                                     20821
# 498                                     26384
# 499                                      2278
# 500                                      2081
# 501                                      5185
# 502                                      2349
# 503                                    326931
# ...

# %%
# Average salaries per college major
df.plot.barh(x='Education.Major', y='Salaries.Mean', figsize=(10, 20))
# Out:
# <AxesSubplot:ylabel='Education.Major'>
